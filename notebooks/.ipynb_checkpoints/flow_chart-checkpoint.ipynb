# %%
# !pip install flowgiston

# %%
from flowgiston import FlowgistonChart

# chart.node("Hello, world")
# chart

# %%
# dir(chart)

# %%
chart = FlowgistonChart()
start = chart.start('run_logs_pipeline(args)')

# %%
step1 = start.edge(chart.process('- get parent folder \n- data folder: specified on args '))

# %%
chart
